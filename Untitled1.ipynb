# %% [markdown]
# <a href="https://colab.research.google.com/github/kulunud/DiffusionProject/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://kulunud: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@github.com/kulunud/DiffusionProject.git
# Out:
# Cloning into 'DiffusionProject'...
# remote: Enumerating objects: 67, done.
# remote: Counting objects: 100% (67/67), done.
# remote: Compressing objects: 100% (44/44), done.
# remote: Total 67 (delta 35), reused 46 (delta 23), pack-reused 0
# Unpacking objects: 100% (67/67), done.

# %%
# %cd DiffusionProject
# Out:
# /content/DiffusionProject

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-3-4996ee3d8d09> in <module>
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/gdrive')
#
# /usr/local/lib/python3.7/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#     104       timeout_ms=timeout_ms,
#     105       ephemeral=True,
# --> 106       readonly=readonly)
#     107
#     108
#
# /usr/local/lib/python3.7/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     123   if ephemeral:
#     124     _message.blocking_request(
# --> 125         'request_auth', request={'authType': 'dfs_ephemeral'}, timeout_sec=None)
#     126
#     127   mountpoint = _os.path.expanduser(mountpoint)
#
# /usr/local/lib/python3.7/dist-packages/google/colab/_message.py in blocking_request(request_type, request, timeout_sec, parent)
#     169   request_id = send_request(
#     170       request_type, request, parent=parent, expect_reply=True)
# --> 171   return read_reply_from_input(request_id, timeout_sec)
#
# /usr/local/lib/python3.7/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#     100         reply.get('colab_msg_id') == message_id):
#     101       if 'error' in reply:
# --> 102         raise MessageError(reply['error'])
#     103       return reply.get('data', None)
#     104
#
# MessageError: Error: credential propagation was unsuccessful

# %%
path = F"/content/gdrive/My Drive/unconditional_ckpt.pt"

# %%
import torch

import ddpm2
import modules
import utils2
from modules import UNet

from ddpm import Diffusion

# %%
device = "cuda"
model = UNet().to(device)
ckpt = torch.load(path)
model.load_state_dict(ckpt)
diffusion = Diffusion(img_size=64, device=device)
x = diffusion.sample(model, n=16)
# Out:
# 999it [03:28,  4.80it/s]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-649380bd5bf0> in <module>
#       5 diffusion = Diffusion(img_size=64, device=device)
#       6 x = diffusion.sample(model, n=16)
# ----> 7 plot_images(x)
#
# NameError: name 'plot_images' is not defined

# %%
from utils import plot_images
plot_images(x)

# %%
import torchvision
dataset = torchvision.datasets.CIFAR10(root='data/',train = True, download=True)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to data/cifar-10-python.tar.gz
#   0%|          | 0/170498071 [00:00<?, ?it/s]
# Extracting data/cifar-10-python.tar.gz to data/

# %%
#so we cant rely on checkpoint, have to train Unet again
from ddpm2 import train
def launch():
    import argparse
    parser = argparse.ArgumentParser()
    args, unknown = parser.parse_known_args()
    args.run_name = "DDPM_Uncondtional"
    args.epochs = 300
    args.batch_size = 14
    args.image_size = 64
    args.dataset_path = r"/content/DiffusionProject/data"  #need to change this
    args.device = "cuda"
    args.lr = 3e-4
    train(args)

# %%
import argparse
from torch.utils.data import DataLoader
import torchvision

#prelim arguments for training
parser = argparse.ArgumentParser()
args, unknown = parser.parse_known_args()
args.run_name = "DDPM_Uncondtional"
args.epochs = 300
args.batch_size = 6
args.image_size = 64
args.dataset_path = r"/content/DiffusionProject/data"  #need to change this
args.device = "cuda"
args.lr = 3e-4

#dataset
transforms = torchvision.transforms.Compose([
        torchvision.transforms.Resize(80),  # args.image_size + 1/4 *args.image_size
        torchvision.transforms.RandomResizedCrop(args.image_size, scale=(0.8, 1.0)),
        torchvision.transforms.ToTensor(),
        torchvision.transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
    ])
dataset = torchvision.datasets.CIFAR10(root='data/', download = True, transform=transforms)
dataloader = DataLoader(dataset, batch_size=args.batch_size, shuffle=True)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to data/cifar-10-python.tar.gz
#   0%|          | 0/170498071 [00:00<?, ?it/s]
# Extracting data/cifar-10-python.tar.gz to data/

# %%
from ddpm2 import train
train(args, dataloader)
# Out:
# 0
# 100%|██████████| 8334/8334 [34:08<00:00,  4.07it/s, MSE=0.0141]
# 999it [00:32, 30.29it/s]
# 1
# 100%|██████████| 8334/8334 [33:59<00:00,  4.09it/s, MSE=0.00067]
# 999it [00:32, 30.37it/s]
# 2
# 100%|██████████| 8334/8334 [33:58<00:00,  4.09it/s, MSE=0.000991]
# 999it [00:32, 30.51it/s]
# 3
# 100%|██████████| 8334/8334 [33:56<00:00,  4.09it/s, MSE=0.00211]
# 999it [00:32, 30.53it/s]
# 4
# 100%|██████████| 8334/8334 [33:55<00:00,  4.10it/s, MSE=0.00529]
# 999it [00:32, 30.54it/s]
# 5
# 100%|██████████| 8334/8334 [33:57<00:00,  4.09it/s, MSE=0.00785]
# 999it [00:32, 30.40it/s]
# 6
#  42%|████▏     | 3532/8334 [14:26<19:36,  4.08it/s, MSE=0.0117]

# %%
path = F"/content/DiffusionProject/models/DDPM_Uncondtional/ckpt.pt"
device = "cuda"
model = UNet().to(device)
ckpt = torch.load(path)  #new path??
model.load_state_dict(ckpt)
diffusion = Diffusion(img_size=64, device=device)
x = diffusion.sample(model, n=16)
# Out:
# 999it [03:18,  5.04it/s]

# %%
from utils2 import plot_images
plot_images(x)
